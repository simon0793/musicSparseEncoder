# %%
# %matplotlib notebook
from pylab import*
from scipy.io import wavfile
import IPython

# %%
sampFreq, snd = wavfile.read('./trainWav/mary had a little lamb.wav')

# %%
print(snd.dtype)
# Out:
# int16

# %%
snd = snd / (2.**15)
s1 = snd[:,0]

# %%
timeArray = arange(0, snd.shape[0], 1)
timeArray = timeArray / sampFreq
timeArray = timeArray * 1000  #scale to milliseconds

# %%
plot(timeArray[:10], s1[:10], color='k')
ylabel('Amplitude')
xlabel('Time (ms)')
# Out:
# <img src="data:image/png;base64,...">

# %%
n = len(s1) 
p = fft(s1) # take the fourier transform

# %%
nUniquePts = int(ceil((n+1)/2.0))
p = p[0:nUniquePts]
p = abs(p)

# %%
p = p / float(n) # scale by the number of points so that
                 # the magnitude does not depend on the length 
                 # of the signal or on its sampling frequency  
p = p**2  # square it to get the power 

# multiply by two (see technical document for details)
# odd nfft excludes Nyquist point
if n % 2 > 0: # we've got odd number of points fft
    p[1:len(p)] = p[1:len(p)] * 2
else:
    p[1:len(p) -1] = p[1:len(p) - 1] * 2 # we've got even number of points fft

freqArray = arange(0, nUniquePts, 1.0) * (sampFreq / n);
plot(freqArray/1000, 10*log10(p), color='k')
xlabel('Frequency (kHz)')
ylabel('Power (dB)')

# %%
from sklearn.linear_model import LinearRegression
import random

# %%
d = int(second / 64)
second = sampFreq
length = 5*second
X = np.fliplr([s1[i:i+d] for i in range(0,(length - d + 1))])
Y = s1[d:(length + 1)]
print(X.shape)
print(Y.shape)
# Out:
# (219812, 689)
# (219812,)

# %%
regressor = LinearRegression(normalize=True)
regressor.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=True)

# %%
start = 25*second + 1048
end = start + 2*second
length = end - start + 1
song = np.zeros((length,))
frame = s1[start:start+d]
numRandom = 0
count = second
for i in range(count):
#     X_test = np.fliplr([s1[i:i+d] for i in range(start,(end - d + 1))])
    nextNote = regressor.predict(np.fliplr(frame[np.newaxis, :]))
    if nextNote[0] <= -1:
        numRandom += 1
        nextNote[0] = random.uniform(-1, -0.5)
    if nextNote[0] >= 1:
        numRandom += 1
        nextNote[0] = random.uniform(0.5, 1)
    song[i] = nextNote[0]
    frame = np.roll(frame, -1)
#     if i % 2 == 0:
    frame[d-1] = nextNote[0]
    if abs(nextNote[0]) < 0.001:
        numRandom += 1
        temp = start + i
        frame = s1[temp:temp+d]
print("Percent random: " + str(100*numRandom/count))
# Out:
# Percent random: 1.6417233560090703

# %%
print(song[:100])
# Out:
# [ 0.06826645  0.0648502   0.06112556  0.05718759  0.05304115  0.04861361
#   0.04378158  0.03839886  0.03242861  0.02596028  0.01922646  0.01263101
#   0.00660664  0.00151685 -0.00243013 -0.00522952 -0.00699657 -0.00784297
#  -0.00776762 -0.00667697 -0.00436867 -0.00064727  0.00457657  0.01120329
#   0.01884511  0.02694141  0.03490532  0.04220265  0.04844945  0.0533548
#   0.05675697  0.05856675  0.05872771  0.05726098  0.05424661  0.04984516
#   0.04425875  0.03770041  0.03040962  0.02266612  0.01475073  0.00684138
#  -0.00102776 -0.00890633 -0.01686935 -0.02491408 -0.03302144 -0.04110682
#  -0.04906086 -0.05673182 -0.06398489 -0.07078426 -0.07718698 -0.08336238
#  -0.08944036 -0.09543507 -0.1012837  -0.10683356 -0.1118986  -0.11629914
#  -0.11991144 -0.12272153 -0.12479526 -0.12621938 -0.12703465 -0.12722716
#  -0.12667582 -0.12524267 -0.12275605 -0.11908278 -0.11411727 -0.10787751
#  -0.10048303 -0.09219599 -0.08332405 -0.07421483 -0.06517603 -0.05642409
# ...

# %%
print(song.shape)
print(np.unique(song).shape)
generatedSong = (song * (2.**15)).astype(np.int16)
wavfile.write('linearGen.wav', sampFreq, generatedSong)
# Out:
# (88201,)
# (44101,)

# %%
actualSong = (s1[start:end] * (2.**15)).astype(np.int16)
wavfile.write('actual.wav', sampFreq, actualSong)

# %%
IPython.display.Audio("linearGen.wav")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
IPython.display.Audio("actual.wav")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
